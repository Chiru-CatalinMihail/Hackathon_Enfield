# %% [markdown]
# ### MACROS

# %%
WEIGHT_DECAY_NAME = 'weight_decay'
LEARNING_RATE_NAME = 'lr'
BATCH_SIZE_NAME = 'BATCH_SIZE'
COLOUR_CHANNELS_NAME = 'COLOUR_CHANNELS'
NO_STACKED_IMGS_NAME = 'NO_STACKED_IMGS'
KEYS_NAME = 'KEYS'

# %% [markdown]
# ### IMPORTS

# %%
# !pip install albumentations

# %%
import os
import warnings
warnings.filterwarnings("ignore") # remove some scikit-image warnings

# import monai
# # monai.config.print_config()

from monai.apps import DecathlonDataset
from monai.data import DataLoader, CacheDataset, decollate_batch
# # from monai.data import decollate_patient_batch
# from monai.utils import first, set_determinism
from monai.networks.nets import UNet, DynUNet, AttentionUnet, ViTAutoEnc, UNETR
from monai.networks.layers import Norm
from monai.metrics import DiceMetric, MeanIoU, compute_average_surface_distance, DiceHelper
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
# import albumentations as A
from monai.transforms import (
    LoadImage,
    LoadImageD,
    EnsureChannelFirstD,
#     AddChannelD,
    ScaleIntensityD,
    ToTensorD,
    Compose,
    AsDiscreteD,
    SpacingD,
    OrientationD,
    ResizeD,
    RandAffineD,
    AsDiscrete,
    AsDiscreted,
    EnsureTyped,
    EnsureType,
    LoadImageD,
    EnsureChannelFirstD,
    OrientationD,
    SpacingD,
    ScaleIntensity,
    ResizeD,
    RandAffineD,
    RandFlipD,
    RandRotateD,
    RandZoomD,
#     RandDeformD,
    ToTensorD,
    Activations, AsDiscrete
)

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader as TorchDataLoader
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2
import sys
from tqdm import tqdm
import pandas as pd
import pickle as pkl
import yaml

import nibabel as nib

from torch.utils.data.dataloader import default_collate

# from hyperparams import *

# %%
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ### HYPERPARAMS ###

# %%
config_path = './config.yaml'

with open("config.yaml", "r") as file:
    config = yaml.load(file, Loader=yaml.FullLoader)

# %%
config
# Out:
# {'BATCH_SIZE': 16,
#  'COLOUR_CHANNELS': 1,
#  'KEYS': ['image', 'label'],
#  'LEARNING_RATE': 0.03,
#  'MAX_EPOCHS': 10,
#  'NO_STACKED_IMGS': 6,
#  'UNet_metadata': {'channels': (16, 32, 32, 128),
#   'dropout': 0.1,
#   'in_channels': 1,
#   'kernel_size': (5, 5, 5),
#   'norm': 'BATCH',
#   'num_res_units': 4,
#   'out_channels': 2,
#   'spatial_dims': 3,
#   'strides': (1, 1, 1)},
#  'VALIDATION_INTERVAL': 2,
#  'decayRate': 0.96}

# %%
BATCH_SIZE = 16

COLOUR_CHANNELS = config[COLOUR_CHANNELS_NAME]
NO_STACKED_IMGS = config[NO_STACKED_IMGS_NAME]

KEYS = config[KEYS_NAME]

# %%
### HYPERPARAMS ###
crt_dir = os.getcwd()
datasets_path = f'./datasets/Trimmed_MSD/'

model_name = 'unet'
checkpoints_path = f'{crt_dir}/checkpoints/{model_name.upper()}/'

DEBUG_MODE = True

# %% [markdown]
# ### MAIN ###

# %%
# Initialize torch and cuda
cuda = torch.cuda.is_available()

# Set device to 3rd GPU
# device = torch.device("cuda:2" if cuda else "cpu")

# Use all GPUs
device = torch.device("cuda" if cuda else "cpu")

print(f'You are using {device}')

print(f'Number of images in a stack: {NO_STACKED_IMGS}')
# Out:
# You are using cuda
# Number of images in a stack: 6

# %%
device
# Out:
# device(type='cuda')

# %%
# Used to bypass this error: https://github.com/pytorch/pytorch/issues/113245
os.environ["CUDA_VISIBLE_DEVICES"]="2,1,0" # "3,2,1,0";  "2, 3"

# %%
os.environ["CUDA_VISIBLE_DEVICES"]
# Out:
# '2,1,0'

# %%
# torch.multiprocessing.set_start_method('spawn', force=True)

# %%
# Set random seed
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %% [markdown]
# # DEBUG FUNCTIONALITIES

# %%
from seg_src.debug_utils import debug_plot_single, debug_plot, plot_prediction_label_side_by_side

# %% [markdown]
# ### PREPROCESSING TRANSFORMS

# %%
# Used Dictionary transforms from MONAI to apply the same transforms to both the image and the label
train_transform = Compose([RandRotateD(range_x=0, range_y=0, range_z=np.pi/12, prob=1, keys=['image', 'label'])])
post_pred = Compose([AsDiscrete(argmax=True, to_onehot= 2)])

# %% [markdown]
# # DATA LOADER

# %%
from seg_src.datasets import msdDatasetTrain, msdDatasetEvaluation, msdDatasetTest

# %%
train_name = "training/"
dev_name = "dev/"
val_name = "validation/"
test_name = "test/"

# %%
datasets_path
# Out:
# './datasets/Trimmed_MSD/'

# %%
"Batch size: ", BATCH_SIZE
# Out:
# ('Batch size: ', 16)

# %%
msd_train_dataset = msdDatasetTrain(datasets_path + train_name, transform = train_transform, tumour_percent_threshold=0.125, samples_proportion=0.7, undersample_flag=True, undersample_size=622) #undersample_size=460)
# Out:
# training
# ./ordered_overlapping_training_indices_stack=6.pkl does not exist. Building the ordered indices.
# 63it [00:24,  2.56it/s]
# ./training_indices_stack=6_samples0.7_batches0.5_undersample=True_size=460.pkl does not exist. Building the overall indices.
# Small tumour stacks 2901
# Small tumour stacks2 460
# Big tumour stacks 1185
# Oversampling factor 1
# Keep undersample indices 1073
# Big tumour stacks2 1073
# Length of small tumour stacks 456
# Length of big tumour stacks 1072
# Length of the dataset 912

# %%
msd_dev_dataset = msdDatasetEvaluation(datasets_path + dev_name)
# Out:
# validation
# ./ordered_nonoverlapping_validation_indices_stack=6.pkl does not exist. Building the ordered indices.

# %%
# Train dataset ar trebui sa fie in jur de 912
len(msd_train_dataset), len(msd_dev_dataset)
# Out:
# (912, 56)

# %%
for i in tqdm(range(len(msd_train_dataset))):
    img, label = msd_train_dataset[i]
    
    debug_plot(img, label)

    if i >= 1:
        break

    if img.max() == 0:
        print("Dataset is corrupted")
        break
# Out:
#   0%|          | 0/912 [00:00<?, ?it/s]
#   0%|          | 1/912 [00:00<13:33,  1.12it/s]
#   0%|          | 1/912 [00:01<28:57,  1.91s/it]

# %%
for i in tqdm(range(len(msd_dev_dataset))):
    img, label = msd_dev_dataset[i]
    
    debug_plot(img, label)

    if i >= 1:
        break

    if img.max() == 0:
        print("Dataset is corrupted")
        break
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]
#   2%|▏         | 1/56 [00:00<00:34,  1.57it/s]
#   2%|▏         | 1/56 [00:01<01:12,  1.32s/it]

# %%
msd_val_dataset = msdDatasetEvaluation(datasets_path + val_name, transform = None)
# Out:
# validation
# ./ordered_nonoverlapping_validation_indices_stack=6.pkl exists. Loading the ordered indices.

# %%
for i in tqdm(range(len(msd_val_dataset))):
    img, label = msd_val_dataset[i]
    
    debug_plot(img, label)

    if i >= 1:
        break

    if img.max() == 0:
        print("Dataset is corrupted")
        break
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]
#   2%|▏         | 1/56 [00:00<00:40,  1.34it/s]
#   2%|▏         | 1/56 [00:01<01:15,  1.37s/it]

# %%
len(msd_train_dataset), len(msd_val_dataset)
# Out:
# (912, 56)

# %%
train_loader = TorchDataLoader(msd_train_dataset, batch_size = BATCH_SIZE, shuffle = False, collate_fn=lambda x: tuple(x_ for x_ in default_collate(x))) # TODO: Comment collate_fn if it doesn't work
dev_loader = TorchDataLoader(msd_dev_dataset, batch_size = BATCH_SIZE, shuffle = False, collate_fn=lambda x: tuple(x_ for x_ in default_collate(x))) # TODO: Comment collate_fn if it doesn't work

# %%
for img, label in tqdm(train_loader):
    break

    # no_healthy, no_ill = 0, 0

    # for i in range(BATCH_SIZE):
    #     if torch.sum(label[i, 0, ...]) > 1e-5:
    #         no_ill += 1
    #     else:
    #         no_healthy += 1

    # print("Healthy", no_healthy, "Ill", no_ill)
# Out:
#   0%|          | 0/57 [00:02<?, ?it/s]

# %%
for img, label in tqdm(dev_loader):
    break
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
val_loader = TorchDataLoader(msd_val_dataset, batch_size = BATCH_SIZE, shuffle = False, collate_fn=lambda x: tuple(x_ for x_ in default_collate(x))) #  num_workers = num_workers,

for _ in tqdm(val_loader):
    break
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
debug_img, debug_label = next(iter(train_loader))

# %%
debug_img.shape, debug_label.shape
# Out:
# (torch.Size([16, 1, 512, 512, 6]), torch.Size([16, 1, 512, 512, 6]))

# %%
input_channels = debug_img.shape[1]
output_channels = 2*input_channels

# %%
debug_img, debug_label = debug_img.to(device), debug_label.to(device)

# %%
debug_plot_single(debug_img, debug_label)

# %% [markdown]
# ## MODEL

# %%
from seg_src.train import  save_checkpoint, load_checkpoint, train

# %% [markdown]
# ### MODEL HYPERPARAMS ###

# %%
# 100 EPOCHS:
UNet_metadata = dict(
    spatial_dims = 3,
    in_channels = 1,
    out_channels = 2,
    channels = (16, 32, 32, 128),
    kernel_size = (5, 5, 5),
    strides = (1, 2, 1, 2),
    num_res_units = 4,
    norm = Norm.BATCH,
    # act = torch.nn.ReLU,
    dropout = 0.1
)

# UNet_metadata = dict(
#     spatial_dims = 3,
#     in_channels = 1,
#     out_channels = 2,
#     channels = (16, 32, 128, 128),
#     kernel_size = (5, 5, 5),
#     strides = (1, 2, 1),
#     num_res_units = 4,
#     norm = Norm.BATCH,
#     # act = torch.nn.ReLU,
#     dropout = 0.1
# )

# %%
# Search available gpu devices for nn.DataParallel

# %%
# # Instantiate model
net = nn.Sequential(nn.BatchNorm3d(1, affine=True), UNet(**UNet_metadata), nn.InstanceNorm3d(2, affine=True))

net = nn.DataParallel(net)# device_ids = [0, 1, 2, 3]
net = net.to(device)


# Xavier initialization
for name, param in net.named_parameters():
    if isinstance(param, nn.Linear):
        nn.init.xavier_normal_(param)
    elif 'bias' in name:
        nn.init.constant_(param, 0.05)

# %%
# net.state_dict()

# %%
debug_img.shape
# Out:
# torch.Size([16, 1, 512, 512, 6])

# %%
net(debug_img).shape
# Out:
# torch.Size([16, 2, 512, 512, 6])

# %%
### LOSS ###
loss_functions = {
    'dice': DiceLoss(to_onehot_y = True, softmax = True, include_background=False),
    'cross_entropy': nn.CrossEntropyLoss(),
    'custom': nn.BCELoss()
}

loss_key = 'dice'

loss_function = loss_functions[loss_key]

# %%
epoch_offset = 0

# %%
LEARNING_RATE = 5e-3
wd = 1e-4

# %%
optimizers = { 'adam' : torch.optim.Adam, 'sgd' : torch.optim.SGD, 'nadam' : torch.optim.NAdam, 'rmsprop' : torch.optim.RMSprop, 'adamw' : torch.optim.AdamW}
optimizer_key = 'nadam'

# Instantiate optimizer
decayRate = 1  #- 1e-3
optimizer = optimizers[optimizer_key](net.parameters(), lr = LEARNING_RATE, weight_decay = wd)

# Instantiate learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=decayRate)

# %%
### PERFORMANCE METRICS ###
dice_metric = DiceHelper(include_background = False, reduction = "mean", get_not_nans=False, ignore_empty=True) # include_background = False,
iou_metric = MeanIoU(include_background=False, reduction = "mean", get_not_nans=False, ignore_empty=True)

# %%
# best_previous_model_name = './checkpoints/UNET/min-max_augmented_unet_nadam_lr5.00e-03_wd1.00e-03_diceloss_epoch82.pth'
# net, optimizer, epoch_offset, loss_function = load_checkpoint(best_previous_model_name, net, optimizer)

# %% [markdown]
# ### TRAINING PROCEDURE ###

# %%
best_model_name = train(net, checkpoints_path, 'UNET',
                        loss_function, loss_key, lr_scheduler,
                        optimizer, optimizer_key, device,
                        msd_train_dataset, train_loader, val_loader,
                        MAX_EPOCHS = 100, VALIDATION_INTERVAL = 2, EPOCH_OFFSET = epoch_offset)
# Out:
# /home/aimas/Desktop/Hackathon_Enfield/checkpoints/UNET/xoxo_nadam_lr5.00e-03_wd1.00e-04_diceloss_best.pth
# ------------
# Epoch 1/2
# 1/57, train_loss: 0.9919
# 2/57, train_loss: 0.9880
# 3/57, train_loss: 0.9877
# 4/57, train_loss: 0.9876
# 5/57, train_loss: 0.9878
# 6/57, train_loss: 0.9924
# 7/57, train_loss: 0.9903
# 8/57, train_loss: 0.9841
# 9/57, train_loss: 0.9909
# 10/57, train_loss: 0.9869
# 11/57, train_loss: 0.9846
# 12/57, train_loss: 0.9896
# 13/57, train_loss: 0.9931
# 14/57, train_loss: 0.9826
# 15/57, train_loss: 0.9803
# 16/57, train_loss: 0.9925
# 17/57, train_loss: 0.9868
# 18/57, train_loss: 0.9885
# 19/57, train_loss: 0.9901
# 20/57, train_loss: 0.9887
# 21/57, train_loss: 0.9805
# 22/57, train_loss: 0.9862
# 23/57, train_loss: 0.9867
# 24/57, train_loss: 0.9869
# 25/57, train_loss: 0.9864
# 26/57, train_loss: 0.9853
# 27/57, train_loss: 0.9828
# 28/57, train_loss: 0.9811
# 29/57, train_loss: 0.9940
# 30/57, train_loss: 0.9846
# 31/57, train_loss: 0.9852
# 32/57, train_loss: 0.9788
# 33/57, train_loss: 0.9759
# 34/57, train_loss: 0.9872
# 35/57, train_loss: 0.9804
# 36/57, train_loss: 0.9853
# 37/57, train_loss: 0.9903
# 38/57, train_loss: 0.9862
# 39/57, train_loss: 0.9819
# 40/57, train_loss: 0.9882
# 41/57, train_loss: 0.9844
# 42/57, train_loss: 0.9886
# 43/57, train_loss: 0.9884
# 44/57, train_loss: 0.9901
# 45/57, train_loss: 0.9889
# 46/57, train_loss: 0.9849
# 47/57, train_loss: 0.9730
# 48/57, train_loss: 0.9913
# 49/57, train_loss: 0.9868
# 50/57, train_loss: 0.9790
# 51/57, train_loss: 0.9894
# 52/57, train_loss: 0.9858
# 53/57, train_loss: 0.9815
# 54/57, train_loss: 0.9824
# 55/57, train_loss: 0.9867
# 56/57, train_loss: 0.9852
# 57/57, train_loss: 0.9777
# epoch 1 average loss: 0.9860
# Saving checkpoint: 1 / 2!!!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2417320/3431775420.py in <module>
# ----> 1 best_model_name = train(net, checkpoints_path, 'xoxo',
#       2                         loss_function, loss_key, lr_scheduler,
#       3                         optimizer, optimizer_key, device,
#       4                         msd_train_dataset, train_loader, val_loader,
#       5                         MAX_EPOCHS = 2, VALIDATION_INTERVAL = 1, EPOCH_OFFSET = epoch_offset)
#
# ~/Desktop/Hackathon_Enfield/seg_src/train.py in train(model, checkpoints_path, model_name, loss_function, loss_key, lr_scheduler, optimizer, optimizer_key, device, train_dataset, train_loader, val_loader, MAX_EPOCHS, VALIDATION_INTERVAL, EPOCH_OFFSET)
#     182
#     183         if epoch % VALIDATION_INTERVAL == 0:
# --> 184             best_dice, best_metrics, best_metric_epoch = validate(model, optimizer, device, val_loader,
#     185                                                                   checkpoints_path, general_name, writer,
#     186                                                                   dice_metric, iou_metric, dice_values, iou_values,
#
# ~/Desktop/Hackathon_Enfield/seg_src/train.py in validate(model, optimizer, device, val_loader, checkpoints_path, general_name, writer, dice_metric, iou_metric, dice_values, iou_values, epoch_loss, epoch, MAX_EPOCHS, VALIDATION_INTERVAL, best_dice, best_metrics, best_metric_epoch, best_model_name)
#      56     print(f"Saving checkpoint: {epoch//VALIDATION_INTERVAL} / {MAX_EPOCHS//VALIDATION_INTERVAL}!!!")
#      57     name = checkpoints_path + f'{general_name}_epoch{epoch}.pth'
# ---> 58     save_checkpoint(epoch, model, optimizer, epoch_loss, name)
#      59
#      60     # Turn model to "eval" mode
#
# ~/Desktop/Hackathon_Enfield/seg_src/train.py in save_checkpoint(epoch, model, optimizer, loss, path)
#      28     ''' Saves the model and optimizer state_dict, along with the loss and epoch number '''
#      29
# ---> 30     torch.save({
#      31             'epoch': epoch,
#      32             'model_state_dict': model.state_dict(),
#
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     616
#     617     if _use_new_zipfile_serialization:
# --> 618         with _open_zipfile_writer(f) as opened_zipfile:
#     619             _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     620             return
#
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in _open_zipfile_writer(name_or_buffer)
#     490     else:
#     491         container = _open_zipfile_writer_buffer
# --> 492     return container(name_or_buffer)
#     493
#     494
#
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in __init__(self, name)
#     461             super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     462         else:
# --> 463             super().__init__(torch._C.PyTorchFileWriter(self.name))
#     464
#     465     def __exit__(self, *args) -> None:
#
# RuntimeError: Parent directory /home/aimas/Desktop/Hackathon_Enfield/checkpoints/UNET does not exist.

# %%
# Get net weights
net.state_dict()
# Out:
# OrderedDict([('module.0.weight', tensor([2.7086], device='cuda:0')),
#              ('module.0.bias', tensor([-2.6364], device='cuda:0')),
#              ('module.0.running_mean', tensor([0.0936], device='cuda:0')),
#              ('module.0.running_var', tensor([0.0222], device='cuda:0')),
#              ('module.0.num_batches_tracked', tensor(7202, device='cuda:0')),
#              ('module.1.model.0.conv.unit0.conv.weight',
#               tensor([[[[[-1.3610e+00, -1.5060e+00, -1.5565e+00, -1.7120e+00, -1.0947e+00],
#                          [-1.5758e+00, -1.7798e+00, -1.9167e+00, -2.0562e+00, -1.3390e+00],
#                          [-1.8840e+00, -2.1444e+00, -2.3577e+00, -2.4360e+00, -1.6384e+00],
#                          [-2.1715e+00, -2.4633e+00, -2.7158e+00, -2.7522e+00, -1.9127e+00],
#                          [-2.4082e+00, -2.7130e+00, -2.9870e+00, -2.9984e+00, -2.1297e+00]],
#
#                         [[-1.4092e+00, -1.6378e+00, -1.7406e+00, -1.9011e+00, -1.2605e+00],
#                          [-1.6092e+00, -1.8880e+00, -2.0715e+00, -2.2031e+00, -1.4717e+00],
#                          [-1.9112e+00, -2.2254e+00, -2.4441e+00, -2.5084e+00, -1.6950e+00],
#                          [-2.1783e+00, -2.5106e+00, -2.7412e+00, -2.7491e+00, -1.8867e+00],
#                          [-2.3636e+00, -2.7050e+00, -2.9497e+00, -2.9358e+00, -2.0411e+00]],
#
#                         [[-1.3161e+00, -1.6105e+00, -1.7355e+00, -1.8618e+00, -1.1495e+00],
#                          [-1.5137e+00, -1.8664e+00, -2.0680e+00, -2.1461e+00, -1.3380e+00],
#                          [-1.8451e+00, -2.2282e+00, -2.4301e+00, -2.4250e+00, -1.5308e+00],
#                          [-2.1375e+00, -2.5307e+00, -2.7290e+00, -2.6445e+00, -1.6815e+00],
#                          [-2.3071e+00, -2.6880e+00, -2.9002e+00, -2.7942e+00, -1.7932e+00]],
#
#                         [[-1.1584e+00, -1.4490e+00, -1.5525e+00, -1.6456e+00, -8.4781e-01],
#                          [-1.3315e+00, -1.6878e+00, -1.8564e+00, -1.9067e+00, -1.0286e+00],
#                          [-1.6538e+00, -2.0488e+00, -2.2246e+00, -2.1904e+00, -1.2212e+00],
#                          [-1.9727e+00, -2.3875e+00, -2.5568e+00, -2.4319e+00, -1.3822e+00],
#                          [-2.1844e+00, -2.5922e+00, -2.7664e+00, -2.5899e+00, -1.4865e+00]],
#
#                         [[-1.0209e+00, -1.2912e+00, -1.3389e+00, -1.3810e+00, -5.3485e-01],
#                         [[ 6.8780e-01,  7.1577e-01,  3.8563e-01,  3.4518e-01, -3.9484e-02],
#                          [ 5.2991e-01,  3.8863e-01, -2.0541e-01, -3.0067e-01, -5.4671e-01],
#                          [ 7.1246e-04, -3.3254e-01, -9.9259e-01, -8.2796e-01, -7.4337e-01],
#                          [-6.5618e-01, -9.5747e-01, -1.4356e+00, -8.8954e-01, -5.4840e-01],
#                          [-1.0671e+00, -1.1651e+00, -1.3741e+00, -5.3920e-01, -9.2659e-02]],
#
#                         [[ 9.2192e-01,  9.5471e-01,  7.1172e-01,  7.5392e-01,  3.7799e-01],
#                          [ 9.4659e-01,  8.6888e-01,  3.2754e-01,  1.9153e-01, -1.2118e-01],
#                          [ 5.7685e-01,  3.4361e-01, -2.9958e-01, -2.8687e-01, -3.4362e-01],
#                          [-5.6869e-02, -2.5176e-01, -7.2633e-01, -3.7543e-01, -2.2387e-01],
#                          [-5.7766e-01, -5.9849e-01, -8.1218e-01, -1.4854e-01,  1.1590e-01]]]]],
#                      device='cuda:0')),
#              ('module.1.model.0.conv.unit0.conv.bias',
#               tensor([ 1.1844e-03, -1.8583e-04, -6.4958e-04, -5.9485e-04,  8.8044e-04,
#                       -3.8240e-04,  1.5486e-04, -3.5984e-04, -6.0860e-04,  4.2139e-04,
#                       -6.3842e-04, -6.7500e-05,  6.4105e-04, -7.4015e-04, -8.7986e-04,
#                       -6.9174e-04], device='cuda:0')),
#              ('module.1.model.0.conv.unit0.adn.N.weight',
#               tensor([  1.3708,  -4.5432,  -0.5882,   3.5185,   4.1075,  46.5407,  -1.2467,
#                        -7.3902,   9.9162, -12.1643,   1.1222,   0.9539,  -3.8649, -14.2550,
#                        29.9901,  -4.4152], device='cuda:0')),
#              ('module.1.model.0.conv.unit0.adn.N.bias',
#               tensor([ -2.5063,  -5.0881, -19.9203, -28.1861, -27.2022,  39.8398, -25.9705,
#                        -5.2474,  28.7819,  -7.7271, -19.0059, -25.6820, -30.3781, -37.4858,
#                        33.1825, -12.0089], device='cuda:0')),
#              ('module.1.model.0.conv.unit0.adn.N.running_mean',
#               tensor([ 533.4401,  -26.1525, -201.5162, -170.7108, -262.1615,  574.4238,
#                        460.5480,   -5.0267,  689.6547, -332.9614,   82.1225,  642.6861,
#                        146.0981,   61.1592,  179.9917,  239.5687], device='cuda:0')),
#              ('module.1.model.0.conv.unit0.adn.N.running_var',
#               tensor([288700.6562,   7316.6436,  68558.2266,  41167.7266,  68626.5078,
#                       464518.7188, 220965.2656,   8259.6016, 527117.0000, 123789.8125,
#                        11889.8770, 433855.6250,  31662.3262,  80518.5000, 142795.2500,
#                        58409.8242], device='cuda:0')),
#              ('module.1.model.0.conv.unit0.adn.N.num_batches_tracked',
#               tensor(7202, device='cuda:0')),
#              ('module.1.model.0.conv.unit0.adn.A.weight',
#               tensor([-0.2699], device='cuda:0')),
#              ('module.1.model.0.conv.unit1.conv.weight',
#               tensor([[[[[-6.3724e-01,  4.5351e-01,  1.3153e-01, -9.3367e-03,  3.4976e-01],
#                          [-6.3936e-01,  4.0515e-01,  5.0709e-02, -7.4086e-02,  3.0002e-01],
#                          [-6.7268e-01,  3.7786e-01,  5.7002e-03, -9.1377e-02,  2.6034e-01],
#                          [-6.7591e-01,  3.8369e-01,  3.8904e-02, -6.4736e-02,  3.0439e-01],
#                          [-3.1508e-01, -1.8500e+00, -1.1534e+00],
#                          [-7.9152e-01, -2.4110e+00, -1.6160e+00]]]],
#
#
#
#                       ...,
#
#
#
#                       [[[[-8.6628e-01, -3.1937e+00,  1.2363e-01],
#                          [-1.3326e+00, -2.6634e+00,  9.0662e-01],
#                          [-2.1430e+00, -4.4147e+00, -5.9220e-01]],
#
#                         [[ 1.2220e-02, -1.4823e+00,  1.7709e+00],
#                          [-5.2775e-01, -1.1235e+00,  2.1368e+00],
#                          [-1.1162e+00, -2.6096e+00,  1.0245e+00]],
#
#                         [[ 4.6100e-01, -2.1036e+00,  1.1502e+00],
#                          [ 8.3719e-02, -1.8049e+00,  1.8312e+00],
#                          [-7.3113e-01, -3.5864e+00,  3.2010e-01]]],
#
#
#                        [[[-1.1852e+00, -3.3365e-02,  6.2355e-01],
#                          [-8.8803e-01,  3.3976e-01,  1.0604e+00],
#                          [-9.5620e-01,  3.4938e-01,  9.5985e-01]],
#
#                         [[-1.0061e+00, -1.8903e-01,  7.5790e-01],
#                          [-8.6696e-01,  1.7682e-01,  1.1990e+00],
#                          [-6.5838e-01,  2.6298e-01,  1.1217e+00]],
#
#                         [[-1.7360e+00, -7.1029e-01, -2.0565e-01],
#                          [-1.3854e+00, -3.9457e-01,  1.8699e-01],
#                          [-1.4446e+00, -3.1554e-01,  9.3869e-02]]]],
#
#
#
#                       [[[[ 1.3153e+00,  9.6861e+00,  1.0313e+01],
#                          [-1.4292e+00,  4.5920e+00,  5.3156e+00],
#                          [-1.6964e+00,  2.6025e+00,  2.8349e+00]],
#
#                         [[-2.4262e+00,  5.4961e+00,  6.6367e+00],
#                          [-4.6959e+00,  6.0120e-01,  1.7299e+00],
#                          [-4.7591e+00, -7.0433e-01,  1.2713e-01]],
#
#                         [[-7.7939e+00, -6.9891e-02,  1.0681e+00],
#                          [-8.8185e+00, -3.2961e+00, -2.1693e+00],
#                          [-1.0134e+01, -6.0273e+00, -5.1618e+00]]],
#
#
#                        [[[ 1.4001e+01,  1.4830e+01,  7.7982e+00],
#                          [ 1.0453e+01,  1.0802e+01,  4.0121e+00],
#                          [ 1.0824e+01,  1.0876e+01,  3.9880e+00]],
#
#                         [[ 8.9104e+00,  9.2902e+00,  2.9367e+00],
#                          [ 5.3304e+00,  5.1594e+00, -8.1392e-01],
#                          [ 5.9454e+00,  5.5435e+00, -4.4965e-01]],
#
#                         [[ 5.5366e+00,  5.5361e+00, -6.1520e-01],
#                          [ 2.4092e+00,  2.1004e+00, -3.7922e+00],
#                          [ 2.6471e+00,  2.0281e+00, -3.8921e+00]]]],
#
#
#
#                       [[[[-4.7180e-03,  6.7350e-01,  1.6735e-01],
#                          [ 1.0189e-01,  8.1495e-01,  3.7973e-01],
#                          [ 5.3890e-02,  6.3721e-01,  1.7303e-01]],
#
#                         [[-2.9124e-01,  4.9168e-01, -2.7309e-01],
#                          [ 1.0279e-01,  8.3083e-01,  2.5500e-01],
#                          [-1.2278e-01,  6.1673e-01, -1.4688e-01]],
#
#                         [[-4.7910e-01,  5.3439e-02, -4.7388e-01],
#                          [-2.7250e-01,  3.8225e-01, -1.9617e-01],
#                          [-1.9352e-01,  3.6921e-01, -2.4923e-01]]],
#
#
#                        [[[-6.5012e-01,  3.2091e-01, -1.6936e-01],
#                          [-3.9127e-01,  4.9134e-01,  1.6753e-02],
#                          [-6.1544e-01,  4.0213e-01, -1.3022e-01]],
#
#                         [[-6.2129e-01,  3.4155e-01, -1.8363e-01],
#                          [-4.8662e-01,  4.7772e-01, -7.0334e-02],
#                          [-5.4490e-01,  4.5713e-01, -8.8212e-02]],
#
#                         [[-8.7160e-01,  1.2163e-01, -4.1513e-01],
#                          [-5.8605e-01,  2.8389e-01, -2.1139e-01],
#                          [-7.7437e-01,  2.4987e-01, -2.4947e-01]]]]], device='cuda:0')),
#              ('module.1.model.2.0.conv.bias',
#               tensor([-1.1865e-03, -7.5626e-05], device='cuda:0')),
#              ('module.1.model.2.0.adn.N.weight',
#               tensor([35.5272, 37.7379], device='cuda:0')),
#              ('module.1.model.2.0.adn.N.bias',
#               tensor([-20.2811, -30.0389], device='cuda:0')),
#              ('module.1.model.2.0.adn.N.running_mean',
#               tensor([-21290.4668, -82803.4375], device='cuda:0')),
#              ('module.1.model.2.0.adn.N.running_var',
#               tensor([5.5008e+08, 2.9512e+09], device='cuda:0')),
#              ('module.1.model.2.0.adn.N.num_batches_tracked',
#               tensor(7202, device='cuda:0')),
#              ('module.1.model.2.0.adn.A.weight',
#               tensor([2.2922], device='cuda:0')),
#              ('module.1.model.2.1.conv.unit0.conv.weight',
#               tensor([[[[[ 3.9728e+00, -3.0500e-01, -1.2071e+01, -2.2338e+00,  5.6976e-01],
#                          [ 6.4452e+00,  2.3531e+00, -6.9834e+00,  1.2545e+00,  3.6646e+00],
#                          [ 6.8709e+00,  3.6526e+00, -5.6723e+00,  2.8776e+00,  4.4294e+00],
#                          [ 5.7743e+00,  2.5853e+00, -6.3198e+00,  2.0533e+00,  4.5455e+00],
#                          [ 2.2358e+00, -4.0694e-01, -1.0759e+01, -5.0082e-01,  2.1128e+00]],
#
#                         [[ 5.4080e+00,  1.5113e+00, -8.8598e+00,  3.1414e-02,  2.3071e+00],
#                          [ 7.6674e+00,  4.2390e+00, -4.8174e+00,  3.4530e+00,  5.2704e+00],
#                          [ 8.7303e+00,  5.1689e+00, -3.4666e+00,  5.0173e+00,  6.2374e+00],
#                          [ 7.5369e+00,  4.4476e+00, -4.0202e+00,  4.6545e+00,  6.2170e+00],
#                          [ 4.4153e+00,  1.7916e+00, -7.4244e+00,  2.0718e+00,  4.0253e+00]],
#
#                         [[ 5.5271e+00,  1.9319e+00, -8.4176e+00,  9.0181e-01,  3.0367e+00],
#                          [ 8.2578e+00,  4.7573e+00, -4.1963e+00,  4.0670e+00,  6.1872e+00],
#                          [ 9.3998e+00,  6.3426e+00, -3.2246e+00,  6.1422e+00,  7.4716e+00],
#                          [ 8.6307e+00,  5.4719e+00, -2.9690e+00,  5.5285e+00,  7.3297e+00],
#                          [ 8.2061e+00,  5.4101e+00,  1.9519e+01,  7.4897e+00,  8.0133e+00]]],
#
#
#                        [[[ 1.2196e+01,  6.3127e+00,  1.0250e+01,  4.8488e+00,  1.0487e+01],
#                          [ 9.1782e+00,  2.7436e+00,  6.6056e+00,  1.6274e+00,  8.1292e+00],
#                          [ 6.0057e+00, -9.2946e-01,  2.9141e+00, -1.2250e+00,  5.6217e+00],
#                          [ 1.0451e+01,  3.9451e+00,  8.4762e+00,  3.5746e+00,  9.7550e+00],
#                          [ 1.6332e+01,  1.0667e+01,  1.5103e+01,  1.0219e+01,  1.5153e+01]],
#
#                         [[ 9.1902e+00,  2.6857e+00,  6.6467e+00,  1.8355e+00,  8.4613e+00],
#                          [ 5.8789e+00, -1.5796e+00,  2.8067e+00, -1.7213e+00,  5.8775e+00],
#                          [ 2.7230e+00, -5.4252e+00, -1.5632e+00, -5.0637e+00,  3.2384e+00],
#                          [ 6.7811e+00, -7.5412e-01,  3.4680e+00, -5.1104e-01,  7.1311e+00],
#                          [ 1.2973e+01,  5.9858e+00,  1.0497e+01,  6.0631e+00,  1.2508e+01]],
#
#                         [[ 7.8385e+00,  5.3149e-01,  4.1956e+00, -3.0804e-01,  7.5532e+00],
#                          [ 4.0471e+00, -3.9316e+00,  1.1577e-01, -3.8570e+00,  4.6126e+00],
#                          [ 5.3375e-01, -8.5484e+00, -5.9685e+00, -8.0597e+00,  1.4878e+00],
#                          [ 4.8816e+00, -3.7774e+00,  3.6103e-01, -3.3267e+00,  5.6153e+00],
#                          [ 1.0852e+01,  3.0955e+00,  7.0333e+00,  3.3574e+00,  1.0970e+01]],
#
#                         [[ 1.0735e+01,  3.5692e+00,  7.5375e+00,  2.6931e+00,  1.0121e+01],
#                          [ 6.7426e+00, -1.2958e+00,  2.9562e+00, -1.5266e+00,  7.0549e+00],
#                          [ 2.9452e+00, -6.0608e+00, -2.2597e+00, -5.3715e+00,  4.1041e+00],
#                          [ 7.0364e+00, -1.4805e+00,  3.1371e+00, -1.0573e+00,  7.8642e+00],
#                          [ 1.3383e+01,  5.5053e+00,  9.7872e+00,  5.7563e+00,  1.3400e+01]],
#
#                         [[ 1.5862e+01,  8.9786e+00,  1.3400e+01,  8.0462e+00,  1.4476e+01],
#                          [ 1.1777e+01,  4.4157e+00,  8.8982e+00,  4.1163e+00,  1.1839e+01],
#                          [ 8.3698e+00, -1.8484e-01,  3.8535e+00,  3.7533e-01,  8.8993e+00],
#                          [ 1.2817e+01,  4.5769e+00,  9.4883e+00,  5.0000e+00,  1.2961e+01],
#                          [ 1.8898e+01,  1.1719e+01,  1.6388e+01,  1.1838e+01,  1.8160e+01]]]]],
#                      device='cuda:0')),
#              ('module.1.model.2.1.conv.unit0.conv.bias',
#               tensor([ 0.0009, -0.0005], device='cuda:0')),
#              ('module.2.weight', tensor([14.3101, 19.2719], device='cuda:0')),
#              ('module.2.bias', tensor([ 41.8248, -41.8248], device='cuda:0'))])

# %%
best_model_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1711567/853553729.py in <module>
# ----> 1 best_model_name
#
# NameError: name 'best_model_name' is not defined

# %%
# %load_ext tensorboard
# %reload_ext tensorboard

# %tensorboard --logdir=./pytorch_logging/unet_adam_lr3.00e-03_diceloss_epochs50/

# %% [markdown]
# ### VALIDATION PROCEDURE ###

# %%
val_name = './checkpoints/UNET/min-max3_augmented_unet_nadam_lr5.00e-04_wd1.00e-03_diceloss_epoch2.pth'

# %%
val_net = net

# %%
# TODO: Verificat dupa ce rezolv restul lucrurilor de ce nu merge loadul ca lumea
val_net = nn.Sequential(nn.BatchNorm3d(1, affine=True), UNet(**UNet_metadata), nn.InstanceNorm3d(2, affine=True))
val_net = nn.DataParallel(val_net, device_ids = [0, 1, 2, 3])
val_net = val_net.to(device)
val_net.load_state_dict(torch.load(val_name))

# %%
# IDIOT PROOF "IT WORKS WELL" TEST - VALIDATION LOADER #
for val_data1 in val_loader:
    val_input1, val_label1 = val_data1
    break

they_are_ordered = True

for i in range(val_input1.shape[0]):
    they_are_ordered &= (val_input1[i] == msd_val_dataset[i][0]).all()

print(f"Same order test1: {they_are_ordered}")

i = 3
skipped_images = 0
for val_data2 in val_loader:
    if i > 0:
        i -= 1
        skipped_images += val_data2[0].shape[-1]
        continue
    else:
        val_input2, val_label2 = val_data2
        break

print(f"No of skipped images: {skipped_images}")
for j in range(3*val_input2.shape[0], 4*val_input2.shape[0]):
    print("Index of image in batch: ", j % val_input2.shape[0], " || ", "Index of image in dataset: ", j)
    
    they_are_ordered &= (val_input2[j % val_input2.shape[0]] == msd_val_dataset[j][0]).all()

    # for idx in range(6):
    #     fig, ax = plt.subplots(1, 2)
    #     ax[0].imshow(val_input2[j % val_input2.shape[0]][0, ..., idx])
    #     ax[1].imshow(msd_val_dataset[j][0][0, ..., idx])
    #     plt.show()

    

print(f"Same order test2: {they_are_ordered}")
# Out:
# Same order test1: True
# No of skipped images: 18
# Index of image in batch:  0  ||  Index of image in dataset:  48
# Index of image in batch:  1  ||  Index of image in dataset:  49
# Index of image in batch:  2  ||  Index of image in dataset:  50
# Index of image in batch:  3  ||  Index of image in dataset:  51
# Index of image in batch:  4  ||  Index of image in dataset:  52
# Index of image in batch:  5  ||  Index of image in dataset:  53
# Index of image in batch:  6  ||  Index of image in dataset:  54
# Index of image in batch:  7  ||  Index of image in dataset:  55
# Index of image in batch:  8  ||  Index of image in dataset:  56
# Index of image in batch:  9  ||  Index of image in dataset:  57
# Index of image in batch:  10  ||  Index of image in dataset:  58
# Index of image in batch:  11  ||  Index of image in dataset:  59
# Index of image in batch:  12  ||  Index of image in dataset:  60
# Index of image in batch:  13  ||  Index of image in dataset:  61
# Index of image in batch:  14  ||  Index of image in dataset:  62
# Index of image in batch:  15  ||  Index of image in dataset:  63
# Same order test2: True

# %%
# IDIOT PROOF "IT WORKS WELL" TEST - LR SCHEDULER LOADER #
future_lr1 = lr_scheduler.get_last_lr()[0] * decayRate

lr_scheduler.step()
future_lr2 = lr_scheduler.get_last_lr()[0]

print(f"LR works as expected: {future_lr1 == future_lr2}")
# Out:
# LR works as expected: True

# %%
qualitative_plots_flag = False
save_qualitative_plots_flag = False

# %%
### PERFORMANCE METRICS ###
dice_metric_eval = DiceHelper(include_background = False, reduction = "mean", get_not_nans=False, ignore_empty=True) # include_background = False,
iou_metric_eval = MeanIoU(include_background=False, reduction = "mean", get_not_nans=False, ignore_empty=True)

# %%
if save_qualitative_plots_flag:
    if not os.path.exists('./plots'):
        os.mkdir('./plots')
        os.mkdir(f'./plots/{model_name.upper()}')
        os.mkdir(f'./plots/{model_name.upper()}/images')
        os.mkdir(f'./plots/{model_name.upper()}/gifs')

    if not os.path.exists(f'./plots/{model_name.upper()}'):
        os.mkdir(f'./plots/{model_name.upper()}')
        os.mkdir(f'./plots/{model_name.upper()}/images')
        os.mkdir(f'./plots/{model_name.upper()}/gifs')

# %%
def precision_score_(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    total_pixel_pred = np.sum(pred_mask)
    precision = np.mean(intersect/total_pixel_pred)
    return round(precision, 3)

def recall_score_(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    total_pixel_truth = np.sum(groundtruth_mask)

    if total_pixel_truth == 0:
        if np.sum(pred_mask) == 0:
            return 1
        else:
            return 0

        
    recall = np.mean(intersect/total_pixel_truth)
    return round(recall, 3)

def dice_coef(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    total_sum = np.sum(pred_mask) + np.sum(groundtruth_mask)
    dice = np.mean(2*intersect/total_sum)
    return round(dice, 3) #round up to 3 decimal places

def iou(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    union = np.sum(pred_mask) + np.sum(groundtruth_mask) - intersect
    iou = np.mean(intersect/union)
    return round(iou, 3)

# %%
import torchvision


shrinker = torchvision.transforms.Resize((128, 128), interpolation=2)


def compress_volume(shrinker, image):
    '''Compresses the volume to 128x128xDepth'''

    compressed_volume = torch.zeros((image.shape[0], image.shape[1], 128, 128, image.shape[-1]))
#     print(compressed_volume.shape)
#     print(image[0, 0, ..., 0].shape)
#     print(shrinker(image[0, 0, ..., 0].unsqueeze(0)).squeeze().shape)

    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            for k in range(image.shape[-1]):
                compressed_volume[i, j, ..., k] = shrinker(image[i, j, ..., k].unsqueeze(0)).squeeze()

    return compressed_volume.to(device)


debug_label = torch.rand((16, 2, 512, 512, 6))

compress_volume(shrinker, debug_label).shape
# Out:
# torch.Size([16, 2, 128, 128, 6])

# %%
no_val_iters = 0
loss_val = []
dice_val = []
iou_val = []
precision_val = []
recall_val = []

post_pred = Compose([AsDiscrete(argmax=True, to_onehot=2)])
post_label = Compose([AsDiscrete(to_onehot=2)])

save_val_data = []

with torch.no_grad():
    val_net.eval()

    count_plots = 0
    idx = 0

    for batch in val_loader:
        val_img, val_label = batch
        val_img, val_label = val_img.to(device), val_label.to(device)

        val_output = val_net(val_img)
        val_output = nn.Softmax(dim=1)(val_output)

        # Shrink to 128x128 both val_output and val_label
        val_output = compress_volume(shrinker, val_output)
        val_label = compress_volume(shrinker, val_label)
        


        # roi_size = (512, 512, 2)
        # sw_batch_size = 1
        # val_outputs_dice = sliding_window_inference(val_img, roi_size, sw_batch_size, val_net)

        # val_outputs_dice = []
        # for val_crt_output in decollate_batch(val_outputs_dice):
        #     print(val_crt_output == None)
        #     print(val_crt_output.shape)
        #     val_outputs_dice.append(post_pred(nn.Softmax(dim=1)(val_crt_output)))

        # val_label_dice = []
        # for crt_label in decollate_batch(val_label):
        #     val_label_dice.append(post_label(crt_label))

        # compute metric for current iteration
        dice_val.append(dice_metric_eval(y_pred=val_output, y=val_label).item())
        # dice_val.append(dice_coef(val_label[1].to('cpu').detach().numpy(), val_output[1].to('cpu').detach().numpy()))
        # precision_val.append(precision_score_(val_label[1].to('cpu').detach().numpy(), val_output[1].to('cpu').detach().numpy()))
        # recall_val.append(recall_score_(val_label[1].to('cpu').detach().numpy(), val_output[1].to('cpu').detach().numpy()))
        # iou_val.append(iou(val_label[1].to('cpu').detach().numpy(), val_output[1].to('cpu').detach().numpy()))
        iou_metric_eval(y_pred=val_output, y=val_label)
        # print("Dice score : ", dice_metric_eval.aggregate().item())
        # print("IoU score : ", iou_metric_eval.aggregate().item())
        # print("Loss : ", loss_function(val_output, val_label).item())

        # dice_val.append(dice_metric_eval.aggregate().item())
        # loss_val.append(loss_function(val_output, val_label).item())
        # iou_val.append(iou_metric_eval.aggregate().item())
        # no_val_iters += 1


        # if recall_val[-1] > 0.8:
        #     save_val_data.append((val_img, val_label, val_output, recall_val[-1]))
        

        if qualitative_plots_flag:
            plot_prediction_label_side_by_side(val_img, val_label, val_output, threshold = 0.5)
            break

        if save_qualitative_plots_flag:

            for i in range(val_img.shape[0]):

                if idx == len(msd_val_dataset):
                    sys.exit()

                print(f"Current index: {idx} / {len(msd_val_dataset)}")
                # Don't save images for the padding indices
                # Only iterate through the unique slices for each patient
                patient_id, slices = msd_val_dataset.stacks_in_order_indices[idx]
                slices = np.unique(slices)
                
                if patient_id > 0:
                    sys.exit()

                im = val_img[i].to('cpu').detach().numpy()
                target = val_label[i].to('cpu').detach().numpy()
                output = val_output[i].to('cpu').detach().numpy()

                # Normalize the output to 0 or 1
                # output = hard_threshold_labels(output)

                idx += 1
                for j in range(len(slices)):
                    plt.imshow(im[0, ..., j], cmap = 'gray')
                    plt.imshow(output[1, ..., j], cmap = 'jet', alpha = 0.5)
                    plt.gca().set_axis_off()

                    plt.savefig(f'./plots/{model_name.upper()}/images/patient{patient_id}_slice{slices[j]}.png')
                    plt.close()

    # Aggregate the final mean results
    dice_score_eval = torch.mean(torch.tensor(dice_val)).item()
    mean_iou_eval = iou_metric_eval.aggregate().item()
    # mean_iou_eval = torch.mean(torch.tensor(iou_val)).item()
    p_score_eval = np.mean(precision_val)
    r_score_eval = np.mean(recall_val)


    # # Reset the status
    # dice_metric_eval.reset()
    # iou_metric_eval.reset()

    print(f"Evaluation metrics: dice: {dice_score_eval:.4f}, iou: {mean_iou_eval:.4f}, precision: {p_score_eval:.4f}, recall: {r_score_eval:.4f}")
# Out:
# Evaluation metrics: dice: 0.0032, iou: 0.0033, precision: nan, recall: nan

# %%
for (val_img, val_label, val_output, crt_recall) in save_val_data:
    
    print(f'Recall score: {crt_recall}')
    for i in range(val_img.shape[-1]):
        im = val_img[0].to('cpu').detach().numpy()
        target = val_label[1].to('cpu').detach().numpy()
        output = val_output[1].to('cpu').detach().numpy()

        fig, axes = plt.subplots(1, 2, figsize=(15, 5))
        axes[0].imshow(im[0, ..., i], cmap = 'gray')
        axes[0].imshow(target[0, ..., i], cmap = 'jet', alpha = 0.5)

        axes[1].imshow(im[0, ..., i], cmap = 'gray')
        axes[1].imshow(output[1, ..., i], cmap = 'jet', alpha = 0.5)

        for j in range(2):
            axes[j].invert_yaxis()
            axes[j].set_axis_off()
            

        plt.show()

# %%
plt.plot(dice_val, label = 'Dice')
plt.plot(iou_val, label = 'IoU')
plt.plot(precision_val, label = 'Precision')
plt.plot(recall_val, label = 'Recall')
plt.plot(loss_val, label = 'Loss')
plt.legend()
plt.show()

# %%
no_val_iters, len(dice_val)
# Out:
# (0, 35)

# %%
# IDIOT PROOF "IT WORKS WELL" TEST - MONAI ONE HOT ENCODING MAP #

from monai.networks.utils import one_hot
# Search for a slice with a tumour

for i in range(len(msd_val_dataset)):
    if(msd_val_dataset[i][1].sum() > 3000):
        single_label = msd_val_dataset[i][1].unsqueeze(0).to('cpu')
        print("OK")
        break

# See how the label looks like
plt.imshow(single_label[0, 0, ..., 3].to('cpu').detach().numpy(), cmap = 'gray')
plt.show()


print("ONE HOT ENCODING TEST")
# See how the one-hot encoding looks like splitted in background and tumour
one_hot_lbl = one_hot(single_label, 2)
one_hot_lbl = one_hot_lbl.detach().cpu().numpy()

plt.imshow(one_hot_lbl[0, 0, ..., 3], cmap = 'gray')
plt.show()
plt.imshow(one_hot_lbl[0, 1, ..., 3], cmap = 'gray')
plt.show()
# Out:
# OK
# ONE HOT ENCODING TEST

# %% [markdown]
# ###  TEST SETUP

# %%
from seg_src.eval import generate_predictions

# %%
generate_predictions(net, msd_test_dataset, test_loader, device)
# Out:
# 100%|██████████| 94/94 [04:04<00:00,  2.61s/it]
# 100%|██████████| 32/32 [03:54<00:00,  7.34s/it]

# %% [markdown]
# ### NUMBER OF TRAINABLE PARAMETERS

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad:
            continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params += params
    print(table)
    # Get the total number of parameters as millions
    print(f"Total Trainable Params: {total_params/1e6:.2f} M params")
    return total_params
    
count_parameters(net)
# Out:
# +----------------------------------------------------------------------------+------------+
# |                                  Modules                                   | Parameters |
# +----------------------------------------------------------------------------+------------+
# |                              module.0.weight                               |     1      |
# |                               module.0.bias                                |     1      |
# |                  module.1.model.0.conv.unit0.conv.weight                   |    2000    |
# |                   module.1.model.0.conv.unit0.conv.bias                    |     16     |
# |                  module.1.model.0.conv.unit0.adn.N.weight                  |     16     |
# |                   module.1.model.0.conv.unit0.adn.N.bias                   |     16     |
# |                  module.1.model.0.conv.unit0.adn.A.weight                  |     1      |
# |                  module.1.model.0.conv.unit1.conv.weight                   |   32000    |
# |                   module.1.model.0.conv.unit1.conv.bias                    |     16     |
# |                  module.1.model.0.conv.unit1.adn.N.weight                  |     16     |
# |                   module.1.model.0.conv.unit1.adn.N.bias                   |     16     |
# |                  module.1.model.0.conv.unit1.adn.A.weight                  |     1      |
# |                  module.1.model.0.conv.unit2.conv.weight                   |   32000    |
# |                   module.1.model.0.conv.unit2.conv.bias                    |     16     |
# |                  module.1.model.0.conv.unit2.adn.N.weight                  |     16     |
# |                   module.1.model.0.conv.unit2.adn.N.bias                   |     16     |
# |                  module.1.model.0.conv.unit2.adn.A.weight                  |     1      |
# |                  module.1.model.0.conv.unit3.conv.weight                   |   32000    |
# |                   module.1.model.0.conv.unit3.conv.bias                    |     16     |
# |                  module.1.model.0.conv.unit3.adn.N.weight                  |     16     |
# |                   module.1.model.0.conv.unit3.adn.N.bias                   |     16     |
# |                  module.1.model.0.conv.unit3.adn.A.weight                  |     1      |
# |                      module.1.model.0.residual.weight                      |     16     |
# |                       module.1.model.0.residual.bias                       |     16     |
# |            module.1.model.1.submodule.0.conv.unit0.conv.weight             |   64000    |
# |             module.1.model.1.submodule.0.conv.unit0.conv.bias              |     32     |
# |            module.1.model.1.submodule.0.conv.unit0.adn.N.weight            |     32     |
# |             module.1.model.1.submodule.0.conv.unit0.adn.N.bias             |     32     |
# |            module.1.model.1.submodule.0.conv.unit0.adn.A.weight            |     1      |
# |            module.1.model.1.submodule.0.conv.unit1.conv.weight             |   128000   |
# |             module.1.model.1.submodule.0.conv.unit1.conv.bias              |     32     |
# |            module.1.model.1.submodule.0.conv.unit1.adn.N.weight            |     32     |
# |             module.1.model.1.submodule.0.conv.unit1.adn.N.bias             |     32     |
# |            module.1.model.1.submodule.0.conv.unit1.adn.A.weight            |     1      |
# |            module.1.model.1.submodule.0.conv.unit2.conv.weight             |   128000   |
# |             module.1.model.1.submodule.0.conv.unit2.conv.bias              |     32     |
# |            module.1.model.1.submodule.0.conv.unit2.adn.N.weight            |     32     |
# |             module.1.model.1.submodule.0.conv.unit2.adn.N.bias             |     32     |
# |            module.1.model.1.submodule.0.conv.unit2.adn.A.weight            |     1      |
# |            module.1.model.1.submodule.0.conv.unit3.conv.weight             |   128000   |
# |             module.1.model.1.submodule.0.conv.unit3.conv.bias              |     32     |
# |            module.1.model.1.submodule.0.conv.unit3.adn.N.weight            |     32     |
# |             module.1.model.1.submodule.0.conv.unit3.adn.N.bias             |     32     |
# |            module.1.model.1.submodule.0.conv.unit3.adn.A.weight            |     1      |
# |                module.1.model.1.submodule.0.residual.weight                |   64000    |
# |                 module.1.model.1.submodule.0.residual.bias                 |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit0.conv.weight       |   128000   |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit0.conv.bias        |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit0.adn.N.weight      |     32     |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit0.adn.N.bias       |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit0.adn.A.weight      |     1      |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit1.conv.weight       |   128000   |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit1.conv.bias        |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit1.adn.N.weight      |     32     |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit1.adn.N.bias       |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit1.adn.A.weight      |     1      |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit2.conv.weight       |   128000   |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit2.conv.bias        |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit2.adn.N.weight      |     32     |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit2.adn.N.bias       |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit2.adn.A.weight      |     1      |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit3.conv.weight       |   128000   |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit3.conv.bias        |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit3.adn.N.weight      |     32     |
# |       module.1.model.1.submodule.1.submodule.0.conv.unit3.adn.N.bias       |     32     |
# |      module.1.model.1.submodule.1.submodule.0.conv.unit3.adn.A.weight      |     1      |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit0.conv.weight  |   512000   |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit0.conv.bias   |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit0.adn.N.weight |    128     |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit0.adn.N.bias  |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit0.adn.A.weight |     1      |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit1.conv.weight  |  2048000   |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit1.conv.bias   |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit1.adn.N.weight |    128     |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit1.adn.N.bias  |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit1.adn.A.weight |     1      |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit2.conv.weight  |  2048000   |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit2.conv.bias   |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit2.adn.N.weight |    128     |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit2.adn.N.bias  |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit2.adn.A.weight |     1      |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit3.conv.weight  |  2048000   |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit3.conv.bias   |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit3.adn.N.weight |    128     |
# |  module.1.model.1.submodule.1.submodule.1.submodule.conv.unit3.adn.N.bias  |    128     |
# | module.1.model.1.submodule.1.submodule.1.submodule.conv.unit3.adn.A.weight |     1      |
# |     module.1.model.1.submodule.1.submodule.1.submodule.residual.weight     |    4096    |
# |      module.1.model.1.submodule.1.submodule.1.submodule.residual.bias      |    128     |
# |           module.1.model.1.submodule.1.submodule.2.0.conv.weight           |   138240   |
# |            module.1.model.1.submodule.1.submodule.2.0.conv.bias            |     32     |
# |          module.1.model.1.submodule.1.submodule.2.0.adn.N.weight           |     32     |
# |           module.1.model.1.submodule.1.submodule.2.0.adn.N.bias            |     32     |
# |          module.1.model.1.submodule.1.submodule.2.0.adn.A.weight           |     1      |
# |     module.1.model.1.submodule.1.submodule.2.1.conv.unit0.conv.weight      |   128000   |
# |      module.1.model.1.submodule.1.submodule.2.1.conv.unit0.conv.bias       |     32     |
# |     module.1.model.1.submodule.1.submodule.2.1.conv.unit0.adn.N.weight     |     32     |
# |      module.1.model.1.submodule.1.submodule.2.1.conv.unit0.adn.N.bias      |     32     |
# |     module.1.model.1.submodule.1.submodule.2.1.conv.unit0.adn.A.weight     |     1      |
# |                 module.1.model.1.submodule.2.0.conv.weight                 |   27648    |
# |                  module.1.model.1.submodule.2.0.conv.bias                  |     16     |
# |                module.1.model.1.submodule.2.0.adn.N.weight                 |     16     |
# |                 module.1.model.1.submodule.2.0.adn.N.bias                  |     16     |
# |                module.1.model.1.submodule.2.0.adn.A.weight                 |     1      |
# |           module.1.model.1.submodule.2.1.conv.unit0.conv.weight            |   32000    |
# |            module.1.model.1.submodule.2.1.conv.unit0.conv.bias             |     16     |
# |           module.1.model.1.submodule.2.1.conv.unit0.adn.N.weight           |     16     |
# |            module.1.model.1.submodule.2.1.conv.unit0.adn.N.bias            |     16     |
# |           module.1.model.1.submodule.2.1.conv.unit0.adn.A.weight           |     1      |
# |                       module.1.model.2.0.conv.weight                       |    1728    |
# |                        module.1.model.2.0.conv.bias                        |     2      |
# |                      module.1.model.2.0.adn.N.weight                       |     2      |
# |                       module.1.model.2.0.adn.N.bias                        |     2      |
# |                      module.1.model.2.0.adn.A.weight                       |     1      |
# |                 module.1.model.2.1.conv.unit0.conv.weight                  |    500     |
# |                  module.1.model.2.1.conv.unit0.conv.bias                   |     2      |
# |                              module.2.weight                               |     2      |
# |                               module.2.bias                                |     2      |
# +----------------------------------------------------------------------------+------------+
# Total Trainable Params: 8.11 M params
# 8113223
